# %%
d = {"Key": "Value","Key1": "Value1"}

# %%
d["Key"]
# Out:
# 'Value'

# %%
d.Key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 d.Key
#
# AttributeError: 'dict' object has no attribute 'Key'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2  = {"Key": "Value","Key1": "Value1"}

# %%
ConfigBox(d2)
# Out:
# ConfigBox({'Key': 'Value', 'Key1': 'Value1'})

# %%
d2 = ConfigBox(d2)

# %%
d2
# Out:
# ConfigBox({'Key': 'Value', 'Key1': 'Value1'})

# %%
d2.key
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\box.py:503, in box.box.Box.__getitem__()
#
# KeyError: 'key'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\box.py:536, in box.box.Box.__getattr__()
#
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\box.py:524, in box.box.Box.__getitem__()
#
# BoxKeyError: "'key'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\box.py:538, in box.box.Box.__getattr__()
#
# AttributeError: 'ConfigBox' object has no attribute 'key'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\config_box.py:28, in box.config_box.ConfigBox.__getattr__()
#
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\box.py:552, in box.box.Box.__getattr__()
#
# BoxKeyError: "'ConfigBox' object has no attribute 'key'"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\box.py:503, in box.box.Box.__getitem__()
#
# KeyError: 'key'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\box.py:536, in box.box.Box.__getattr__()
#
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\box.py:524, in box.box.Box.__getitem__()
#
# BoxKeyError: "'key'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\box.py:538, in box.box.Box.__getattr__()
#
# AttributeError: 'ConfigBox' object has no attribute 'key'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 d2.key
#
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\config_box.py:30, in box.config_box.ConfigBox.__getattr__()
#
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\box\box.py:552, in box.box.Box.__getattr__()
#
# BoxKeyError: "'ConfigBox' object has no attribute 'key'"

# %%
d2.Key
# Out:
# 'Value'

# %%
d2.Key1
# Out:
# 'Value1'

# %%
def get_product(x: int, y: int):
    return x * y

# %%
get_product(x = 2, y=3)
# Out:
# 6

# %%
get_product(2, "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x: int, y: int):
    return x * y

# %%
get_product(x = 2, y=3)
# Out:
# 6

# %%
get_product(2, "3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 get_product(2, "3")
#
# File c:\Users\Acer\anaconda3\envs\chestdisease\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001C8C75BEDD0> does not match annotation type <class 'int'>
